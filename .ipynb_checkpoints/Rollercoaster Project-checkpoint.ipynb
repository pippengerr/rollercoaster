# %% [markdown]
# ## Our Rollercoaster Project
# In the first cell, we import pandas, read in the file, and check the column names. Additionally, we convert the height column to floattype, and fill in any nonexistant Duration or Length values with a time of 00:00 or a value of 0.

# %%
import pandas as pd

roller = pd.read_csv('rollercoaster.csv')
roller.columns = roller.columns.str.strip()
roller = roller.rename(columns={"Height (feet)": "Height"})
roller.loc[111, 'Height'] = 200
roller = roller[0: 300]
roller['Duration (min:sec)'] = roller['Duration (min:sec)'].fillna('00:00')
roller['Duration (min:sec)'] = roller['Duration (min:sec)'].replace(' ', '00:00')
roller['Length (feet)'] = roller['Length (feet)'].fillna(0)
roller['Height'] = roller['Height'].astype(float)
roller.columns
# Out:
# Index(['Name', 'Park', 'City/Region', 'City/State/Region', 'Country/Region',
#        'Geographic Region', 'Construction', 'Type', 'Status',
#        'Year/Date Opened', 'Height', 'Speed (mph)', 'Length (feet)',
#        'Inversions (YES or NO)', 'Number of Inversions', 'Drop (feet)',
#        'Duration (min:sec)', 'G Force', 'Vertical Angle (degrees)'],
#       dtype='object')

# %% [markdown]
# ## Functions
# ### Duration Function
# The goal of the duration function is to return a point value based on how long the rollercoaster is. We used datetime to convert the available strings to minutes and seconds, then compared those against our standards. At the end of the function, we create a new column to reflect the duration ranking.

# %%
from datetime import datetime


def mintosec(time):
    new = datetime.strptime(time, '%M:%S')
    minutes = new.strftime("%M:%S")
    return minutes


rollerduration = roller['Duration (min:sec)']


def duration(rollerduration):
    mins = mintosec(rollerduration)
    if mins <= '01:10':
        durationpoints = 1
    elif '01:10' < mins <= '02:20':
        durationpoints = 2
    elif '02:20' < mins <= '03:30':
        durationpoints = 3
    elif '03:30' < mins <= '04:40':
        durationpoints = 4
    elif '04:40' < mins <= '05:50':
        durationpoints = 5
    return durationpoints
    return time


roller['duration rating'] = roller['Duration (min:sec)'].apply(duration)

# %% [markdown]
# ## Length Function
# The goal of the length function is to return a point value based on how many feet long the rollercoaster is. We believe that the longer a coaster, the more fun it is! At the end of the function, we create a new column to reflect the length ranking.

# %%
rollerlength = roller['Length (feet)']


def length(rollerlength):
    points = 0
    if rollerlength <= 1650:
        points += 1
    elif 1650 < rollerlength <= 3330:
        points += 2
    elif 3330 < rollerlength <= 4980:
        points += 3
    elif 4980 < rollerlength <= 6630:
        points += 4
    elif 6630 < rollerlength <= 8280:
        points += 5
    return points


roller['length rating'] = roller['Length (feet)'].apply(length)

# %% [markdown]
# ## Speed
# The goal of the speed function is to return a point value based on how fast the rollercoaster goes. The faster the coaster is able to go, the better it scores. At the end of the function, we create a new column to reflect the speed ranking.

# %%
rollerspeed = roller['Speed (mph)']


def speed(rollerspeed):
    points = 0
    if 25 < rollerspeed <= 50:
        points += 1
    elif 50 < rollerspeed <= 75:
        points += 2
    elif 75 < rollerspeed <= 100:
        points += 3
    elif 100 < rollerspeed <= 125:
        points += 4
    elif 125 <= rollerspeed:
        points += 5
    return points


roller['speed rating'] = roller['Speed (mph)'].apply(speed)

# %% [markdown]
# ## Age
# The more recent a coaster was built, the higher it will score. We prioritize safety! At the end of the function, we create a new column to reflect the age ranking.

# %%
rollerage = roller['Year/Date Opened']


def years(rollerage):
    points = 0
    if rollerage >= 2000:
        points += 5
    if 1980 <= rollerage < 2000:
        points += 4
    if 1960 <= rollerage < 1980:
        points += 3
    if 1940 <= rollerage < 1960:
        points += 2
    if 1920 <= rollerage < 1940:
        points += 1
    if rollerage == 'NaN':
        points += 0
    return points


roller['age rating'] = roller['Year/Date Opened'].apply(years)

# %% [markdown]
# ## Height
# We want our coasters to reach the maximum possible height, so we scored each rollercoaster based on its given height. At the end of the function, we create a new column to reflect the height ranking.

# %%
rollerheight = roller['Height']


def height(rollerheight):
    points = 0
    if rollerheight < 100:
        points += 1
    if 100 <= rollerheight < 200:
        points += 2
    if 200 <= rollerheight < 300:
        points += 3
    if 300 <= rollerheight < 400:
        points += 4
    if 400 <= rollerheight < 500:
        points += 5
    return points


roller['height rating'] = roller['Height'].apply(height)

# %% [markdown]
# ## Inversions
# The more inversions each rollercoaster has, the higher it scores on our algorithm. At the end of the function, we create a new column to reflect the inversion ranking.

# %%
rollerinversions = roller['Number of Inversions']


def inversions(rollerinversions):
    points = 0
    if 1 <= rollerinversions < 3:
        points += 1
    if 3 <= rollerinversions < 5:
        points += 2
    if 5 <= rollerinversions < 7:
        points += 3
    if 7 <= rollerinversions < 9:
        points += 4
    if 9 <= rollerinversions:
        points += 5
    return points


roller['inversions rating'] = roller['Number of Inversions'].apply(inversions)

# %% [markdown]
# ## Final Rating Function
# This function makes a final column that combines the previous ratings

# %%
def finalrating():
    totalrating = rollerage + rollerspeed + rollerduration + rollerheight + rollerinversions
    return totalrating


roller['total rating'] = roller['age rating']+roller['speed rating']+roller['length rating'] + roller['height rating'] + roller['inversions rating']

# %% [markdown]
# ## Final Ranking

# %%
roller.sort_values(by='total rating', ascending=False)
# Out:
#                                  Name  \
# 239                 Steel Dragon 2000
# 146                         Kingda Ka
# 231  Soaring Dragon & Dancing Phoenix
# 131                   Intimidator 305
# 229                            Smiler
# 99                      Formula Rossa
# 103                          Fury 325
# 73                          Dinoconda
# 219                           Scream!
# 124                             Helix
# 282     Velikolukskiy Myasokombinat-2
# 16                            Banshee
# 242                   Steel Vengeance
# 65                      Crazy Coaster
# 250  Superman / la Atracción de Acero
# 148                            Kraken
# 151                         Leviathan
# 6                              Altair
# 161                            Medusa
# 163                  Millennium Force
# 273               Top Thrill Dragster
# 79                          Eejanaika
# 78                       Dragon's Run
# 71                          Desperado
# 58         Coaster Through the Clouds
# 72                        Diamondback
# 74                         Do-Dodonpa
# 76                        Dragon Khan
# 252          Superman Krypton Coaster
# 221                         Shambhala
# ..                                ...
# 138               Journey to Atlantis
# 206                             Raven
# 185                          Oblivion
# 296                            Winjas
# 139               Journey to Atlantis
# 214               Road Runner Express
# 140                  Judge Roy Scream
# 235                          Stampida
# 121                         Half Pipe
# 33      Big Thunder Mountain Railroad
# 188                       Pandemonium
# 82            Eurosat Can Can Coaster
# 234                   SpeedSnake FREE
# 170                      Montana Rusa
# 64                         Crazy Bird
# 169                      Montana Rusa
# 247                     Super Tornado
# 193                           Phoenix
# 189                       Pandemonium
# 223                        Sidewinder
# 220                          Screamer
# 133                       Iron Dragon
# 55              Cedar Creek Mine Ride
# 261                       Taunusblitz
# 66                            Cyclone
# 38                        Blue Streak
# 289                           Whizzer
# 108                      Giant Dipper
# 109                      Giant Dipper
# 57                Coaster Thrill Ride
#
#                                           Park            City/Region  \
# 239                         Nagashima Spa Land              Nagashima
# 146                  Six Flags Great Adventure                Jackson
# 231                  Nanchang Wanda Theme Park                Xinjian
# 131                             Kings Dominion                Doswell
# 229                               Alton Towers                  Alton
# 99                     Ferrari World Abu Dhabi              Abu Dhabi
# 103                                  Carowinds              Charlotte
# 73                        China Dinosaurs Park                 Xinbei
# 219                   Six Flags Magic Mountain               Valencia
# 124                                   Liseberg             Gothenburg
# 282                              Wonder Island       Saint Petersburg
# 16                                Kings Island                  Mason
# 242                                Cedar Point               Sandusky
# 65                 Loca Joy Holiday Theme Park              Yongchuan
# 250                       Parque Warner Madrid  San Martin de la Vega
# 148                           SeaWorld Orlando                Orlando
# 151                        Canada's Wonderland                Vaughan
# 6                              Cinecittà World                   Rome
# 161                Six Flags Discovery Kingdom                Vallejo
# 163                                Cedar Point               Sandusky
# 273                                Cedar Point               Sandusky
# 79                             Fuji-Q Highland            Fujiyoshida
# 78                                 Dragon Park                Ha Long
# 71              Buffalo Bill's Resort & Casino                  Primm
# 58                   Nanchang Wanda Theme Park                Xinjian
# 72                                Kings Island            Kings Mills
# 74                             Fuji-Q Highland            Fujiyoshida
# 76                           PortAventura Park                  Salou
# 252                     Six Flags Fiesta Texas            San Antonio
# 221                          PortAventura Park                  Salou
# ..                                         ...                    ...
# 138                         SeaWorld San Diego              San Diego
# 206                              Holiday World            Santa Claus
# 185                               Alton Towers                  Alton
# 296                              Phantasialand                 Bruhl
# 139                       SeaWorld San Antonio            San Antonio
# 214                     Six Flags Fiesta Texas            San Antonio
# 140                       Six Flags Over Texas              Arlington
# 235                          PortAventura Park                  Salou
# 121                             Elitch Gardens                 Denver
# 33                                  Disneyland                Anaheim
# 188                     Six Flags Fiesta Texas            San Antonio
# 82                                 Europa Park                  Rust
# 234                     Fort Fun Abenteuerland             Wasserfall
# 170                               VulQano Park                  Quito
# 64                                Happy Valley                 Dongli
# 169                             Salitre Magico                 Bogota
# 247  Zoo Safari- und Hollywoodpark Stukenbrock            Stukenbrock
# 193                    Knoebels Amusement Park               Elysburg
# 189                       Six Flags Over Texas              Arlington
# 223                             Elitch Gardens                 Denver
# 220                     Scandia Amusement Park                Ontario
# 133                                Cedar Point               Sandusky
# 55                                 Cedar Point               Sandusky
# 261                          Taunus Wunderland           Schlangenbad
# 66                     Lakeside Amusement Park                 Denver
# 38                                 Cedar Point               Sandusky
# 289                    Six Flags Great America                 Gurnee
# 108                 Santa Cruz Beach Boardwalk             Santa Cruz
# 109                               Belmont Park              San Diego
# 57                               Puyallup Fair               Puyallup
#
#           City/State/Region        Country/Region Geographic Region  \
# 239            Kuwana,, Mie                 Japan              Asia
# 146              New Jersey         United States     North America
# 231       Nanchang, Jiangxi                 China              Asia
# 131                Virginia         United States     North America
# 229  Staffordshire, England        United Kingdom            Europe
# 99                Abu Dhabi  United Arab Emirates       Middle East
# 103          North Carolina         United States     North America
# 73       Changzhou, Jiangsu                 China              Asia
# 219              California         United States     North America
# 124         Vastra Gotaland                Sweden            Europe
# 282        Saint Petersburg                Russia            Europe
# 16                     Ohio         United States     North America
# 242                    Ohio         United States     North America
# 65                Chongqing                 China              Asia
# 250                  Madrid                 Spain            Europe
# 148                 Florida         United States     North America
# 151                 Onterio                Canada     North America
# 6                      Rome                 Italy            Europe
# 161              California         United States     North America
# 163                    Ohio         United States     North America
# 273                    Ohio         United States     North America
# 79                Yamanashi                 Japan              Asia
# 78               Quang Ninh               Vietnam              Asia
# 71                   Nevada         United States     North America
# 58        Nanchang, Jiangxi                 China              Asia
# 72                     Ohio         United States     North America
# 74                Yamanashi                 Japan              Asia
# 76                Tarragona                 Spain            Europe
# 252                   Texas         United States     North America
# 221               Tarragona                 Spain            Europe
# ..                      ...                   ...               ...
# 138              California         United States     North America
# 206                 Indiana         United States     North America
# 185  Staffordshire, England        United Kingdom            Europe
# 296  North Rhine-Westphalia               Germany            Europe
# 139                   Texas         United States     North America
# 214                   Texas         United States     North America
# 140                   Texas         United States     North America
# 235               Tarragona                 Spain            Europe
# 121                Colorado         United States     North America
# 33               California         United States     North America
# 188                   Texas         United States     North America
# 82       Baden Wuerttemberg               Germany            Europe
# 234  North Rhine-Westphalia               Germany            Europe
# 170               Pichincha               Ecuador     South America
# 64                  Tianjin                 China              Asia
# 169            Cundinamarca              Colombia     South America
# 247  North Rhine-Westphalia               Germany            Europe
# 193            Pennsylvania         United States     North America
# 189                   Texas         United States     North America
# 223                Colorado         United States     North America
# 220              California         United States     North America
# 133                    Ohio         United States     North America
# 55                     Ohio         United States     North America
# 261                   Hesse               Germany            Europe
# 66                 Colorado         United States     North America
# 38                     Ohio         United States     North America
# 289                Illinois         United States     North America
# 108              California         United States     North America
# 109              California         United States     North America
# 57               Washington         United States     North America
#
#     Construction       Type      Status  Year/Date Opened      ...       \
# 239        Steel   Sit Down   Operating            2000.0      ...
# 146        Steel   Sit Down   Operating            2005.0      ...
# 231        Steel   Inverted   Operating            2016.0      ...
# 131        Steel   Sit Down   Operating            2010.0      ...
# 229        Steel   Sit Down   Operating            2013.0      ...
# 99         Steel   Sit Down   Operating            2010.0      ...
# 103        Steel   Sit Down   Operating            2015.0      ...
# 73         Steel       Wing   Operating            2012.0      ...
# 219        Steel   Sit Down   Operating            2003.0      ...
# 124        Steel   Sit Down   Operating            2014.0      ...
# 282        Steel   Sit Down   Operating            2017.0      ...
# 16         Steel   Inverted   Operating            2014.0      ...
# 242        Steel   Sit Down   Operating            2018.0      ...
# 65         Steel   Sit Down   Operating            2013.0      ...
# 250        Steel   Sit Down   Operating            2002.0      ...
# 148        Steel   Sit Down   Operating            2000.0      ...
# 151        Steel   Sit Down   Operating            2012.0      ...
# 6          Steel   Sit Down   Operating            2014.0      ...
# 161        Steel   Sit Down   Operating            2000.0      ...
# 163        Steel   Sit Down   Operating            2000.0      ...
# 273        Steel   Sit Down   Operating            2003.0      ...
# 79         Steel       Wing   Operating            2006.0      ...
# 78         Steel   Sit Down   Operating            2017.0      ...
# 71         Steel   Sit Down   Operating            2005.0      ...
# 58         Steel   Sit Down   Operating            2016.0      ...
# 72         Steel   Sit Down   Operating            2009.0      ...
# 74         Steel   Sit Down   Operating            2001.0      ...
# 76         Steel   Sit Down   Operating            1995.0      ...
# 252        Steel   Sit Down  Operating             2000.0      ...
# 221        Steel   Sit Down   Operating            2012.0      ...
# ..           ...        ...         ...               ...      ...
# 138        Steel   Sit Down  Operating             2004.0      ...
# 206         Wood   Sit Down   Operating            1995.0      ...
# 185        Steel   Sit Down   Operating            1998.0      ...
# 296        Steel   Sit Down   Operating            2002.0      ...
# 139        Steel   Sit Down   Operating            2007.0      ...
# 214        Steel   Sit Down  Operating             1997.0      ...
# 140         Wood   Sit Down   Operating            1980.0      ...
# 235         Wood   Sit Down   Operating            1997.0      ...
# 121        Steel   Sit Down   Operating            2004.0      ...
# 33         Steel   Sit Down   Operating            1979.0      ...
# 188        Steel   Sit Down   Operating            2007.0      ...
# 82         Steel   Sit Down   Operating            1989.0      ...
# 234        Steel   Sit Down   Operating            1982.0      ...
# 170        Steel   Sit Down   Operating            2005.0      ...
# 64         Steel   Sit Down   Operating            2013.0      ...
# 169        Steel   Sit Down   Operating            2000.0      ...
# 247        Steel   Sit Down   Operating            1981.0      ...
# 193         Wood   Sit Down   Operating            1985.0      ...
# 189        Steel   Sit Down   Operating            2008.0      ...
# 223        Steel   Sit Down   Operating            1995.0      ...
# 220        Steel   Sit Down   Operating            1995.0      ...
# 133        Steel  Suspended   Operating            1987.0      ...
# 55         Steel      Steel   Operating            1969.0      ...
# 261        Steel   Sit Down   Operating            1999.0      ...
# 66          Wood   Sit Down   Operating            1940.0      ...
# 38          Wood   Sit Down   Operating            1964.0      ...
# 289        Steel   Sit Down   Operating            1976.0      ...
# 108         Wood   Sit Down   Operating            1924.0      ...
# 109         Wood   Sit Down   Operating            1925.0      ...
# 57          Wood   Sit Down   Operating            1935.0      ...
#
#      Duration (min:sec)  G Force  Vertical Angle (degrees) duration rating  \
# 239                4:00                                NaN               4
# 146                0:28      NaN                      90.0               1
# 231               00:00      NaN                       NaN               1
# 131                3:00      NaN                      85.0               3
# 229                2:45      4.5                      50.0               3
# 99                00:00      NaN                       NaN               1
# 103               00:00      NaN                      81.0               1
# 73                00:00      NaN                       NaN               1
# 219                3:00      NaN                       NaN               3
# 124                2:10      4.3                       NaN               2
# 282               00:00      NaN                       NaN               1
# 16                 2:40      NaN                       NaN               3
# 242                2:30      NaN                      90.0               3
# 65                00:00      NaN                       NaN               1
# 250                2:26      NaN                       NaN               3
# 148                2:02      NaN                       NaN               2
# 151                3:28      NaN                      80.0               3
# 6                 00:00      NaN                       NaN               1
# 161                3:15      4.5                       NaN               3
# 163                2:20      NaN                      80.0               2
# 273                0:30      NaN                      90.0               1
# 79                 2:10      NaN                       NaN               2
# 78                00:00      NaN                       NaN               1
# 71                 2:43        4                      60.0               3
# 58                 4:12      NaN                       NaN               4
# 72                 3:00      NaN                       NaN               3
# 74                00:00      NaN                       NaN               1
# 76                 1:45      NaN                       NaN               2
# 252                2:35      NaN                       NaN               3
# 221                3:00      3.8                       NaN               3
# ..                  ...      ...                       ...             ...
# 138                5:25        3                       NaN               5
# 206                1:30      NaN                       NaN               2
# 185                1:15      4.5                      87.0               2
# 296               00:00      NaN                       NaN               1
# 139                3:30      NaN                       NaN               3
# 214                2:24      NaN                       NaN               3
# 140                1:30      NaN                       NaN               2
# 235                1:40      NaN                       NaN               2
# 121                2:00      4.5                       NaN               2
# 33                 3:00      NaN                       NaN               3
# 188               00:00      NaN                       NaN               1
# 82                 3:18        4                       NaN               3
# 234                1:00      NaN                       NaN               1
# 170               00:00      NaN                       NaN               1
# 64                00:00      NaN                     120.0               1
# 169                1:10      NaN                       NaN               1
# 247               00:00      NaN                       NaN               1
# 193                2:00      NaN                       NaN               2
# 189                1:51      NaN                       NaN               2
# 223                1:06        4                       NaN               1
# 220                1:56      NaN                       NaN               2
# 133                2:00      NaN                       NaN               2
# 55                 2:42      NaN                       NaN               3
# 261                1:50      NaN                       NaN               2
# 66                 2:00      NaN                      50.0               2
# 38                 1:45      NaN                       NaN               2
# 289                2:00      NaN                       NaN               2
# 108                1:52      NaN                       NaN               2
# 109               00:00      NaN                       NaN               1
# 57                 1:45      NaN                       NaN               2
#
#      length rating speed rating age rating height rating  inversions rating  \
# 239              5            3          5             4                  0
# 146              2            5          5             5                  0
# 231              3            3          5             2                  3
# 131              4            3          5             4                  0
# 229              3            2          5             1                  5
# 99               4            5          5             2                  0
# 103              4            3          5             4                  0
# 73               3            3          5             3                  2
# 219              3            2          5             2                  4
# 124              3            2          5             2                  4
# 282              2            2          5             2                  5
# 16               3            2          5             2                  4
# 242              4            2          5             3                  2
# 65               2            2          5             2                  5
# 250              3            2          5             2                  4
# 148              3            2          5             2                  4
# 151              4            3          5             4                  0
# 6                2            2          5             2                  5
# 161              3            2          5             2                  4
# 163              4            3          5             4                  0
# 273              2            4          5             5                  0
# 79               3            3          5             3                  2
# 78               3            2          5             2                  3
# 71               4            3          5             3                  0
# 58               4            3          5             3                  0
# 72               4            3          5             3                  0
# 74               3            4          5             2                  1
# 76               3            2          4             2                  4
# 252              3            2          5             2                  3
# 221              4            3          5             3                  0
# ..             ...          ...        ...           ...                ...
# 138              1            1          5             1                  0
# 206              2            1          4             1                  0
# 185              1            2          4             1                  0
# 296              1            1          5             1                  0
# 139              1            0          5             2                  0
# 214              2            1          4             1                  0
# 140              2            1          4             1                  0
# 235              2            1          4             1                  0
# 121              1            1          5             1                  0
# 33               2            1          3             2                  0
# 188              1            1          5             1                  0
# 82               2            1          4             1                  0
# 234              1            1          4             1                  1
# 170              1            0          5             1                  1
# 64               1            0          5             1                  1
# 169              1            0          5             1                  1
# 247              1            1          4             1                  1
# 193              2            1          4             1                  0
# 189              1            1          5             1                  0
# 223              1            1          4             1                  1
# 220              2            1          4             1                  0
# 133              2            1          4             1                  0
# 55               2            1          3             1                  0
# 261              1            1          4             1                  0
# 66               2            2          2             1                  0
# 38               2            1          3             1                  0
# 289              2            1          3             1                  0
# 108              2            2          1             1                  0
# 109              2            2          1             1                  0
# 57               2            1          1             1                  0
#
#      total rating
# 239            17
# 146            17
# 231            16
# 131            16
# 229            16
# 99             16
# 103            16
# 73             16
# 219            16
# 124            16
# 282            16
# 16             16
# 242            16
# 65             16
# 250            16
# 148            16
# 151            16
# 6              16
# 161            16
# 163            16
# 273            16
# 79             16
# 78             15
# 71             15
# 58             15
# 72             15
# 74             15
# 76             15
# 252            15
# 221            15
# ..            ...
# 138             8
# 206             8
# 185             8
# 296             8
# 139             8
# 214             8
# 140             8
# 235             8
# 121             8
# 33              8
# 188             8
# 82              8
# 234             8
# 170             8
# 64              8
# 169             8
# 247             8
# 193             8
# 189             8
# 223             8
# 220             8
# 133             8
# 55              7
# 261             7
# 66              7
# 38              7
# 289             7
# 108             6
# 109             6
# 57              5
#
# [300 rows x 26 columns]

# %%
roller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 26 columns):
# Name                        300 non-null object
# Park                        300 non-null object
# City/Region                 300 non-null object
# City/State/Region           300 non-null object
# Country/Region              300 non-null object
# Geographic Region           300 non-null object
# Construction                300 non-null object
# Type                        300 non-null object
# Status                      300 non-null object
# Year/Date Opened            300 non-null float64
# Height                      299 non-null float64
# Speed (mph)                 296 non-null float64
# Length (feet)               300 non-null float64
# Inversions (YES or NO)      300 non-null object
# Number of Inversions        300 non-null float64
# Drop (feet)                 142 non-null object
# Duration (min:sec)          300 non-null object
# G Force                     83 non-null object
# Vertical Angle (degrees)    91 non-null float64
# duration rating             300 non-null int64
# length rating               300 non-null int64
# speed rating                300 non-null int64
# age rating                  300 non-null int64
# height rating               300 non-null int64
# inversions rating           300 non-null int64
# total rating                300 non-null int64
# dtypes: float64(6), int64(7), object(13)
# memory usage: 61.0+ KB
